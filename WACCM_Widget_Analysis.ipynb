# %%
"""
Originally written by Greg Cooke (pygjc@leeds.ac.uk) & Professor Dan Marsh @ University of Leeds
"""

"""
Code description and information:
    So far this has been set up to analyse output from WACCM6 simulations - specifically the atmosphere component.#
    
    You will need to enter paths to the datasets (netCDF files) you plan to analyse in the 5th cell.
    Once this is done, the code can be run through each cell until the end and the widget can be used.
    The widget is currently designed to take a plotting function and output different plot types.
    If you would like a different plot type to work in the widget, write your function e.g. -> def New_Plot_Type_Func(args)
    Then, in the def final_widget(plot_type) function, add: 
    
    #new plot type
    if (plot_type == 'new plot type name'):
        NPT = interactive(New_Plot_Type_Func, args) #add options to arguments like in other examples
        display(NPT)
        
    Then, make sure in the Final_Widget options for plot_type, you add the string 'new plot type name' to the list.
    
    The commenting is not perfect (neither is the code) and there are plenty of improvements that can be made.
"""
# Out:
# "\nCode description and information:\n    So far this has been set up to analyse output from WACCM6 simulations - specifically the atmosphere component.#\n    \n    You will need to enter paths to the datasets (netCDF files) you plan to analyse in the 5th cell.\n    Once this is done, the code can be run through each cell until the end and the widget can be used.\n    The widget is currently designed to take a plotting function and output different plot types.\n    If you would like a different plot type to work in the widget, write your function e.g. -> def New_Plot_Type_Func(args)\n    Then, in the def final_widget(plot_type) function, add: \n    \n    #new plot type\n    if (plot_type == 'new plot type name'):\n        NPT = interactive(New_Plot_Type_Func, args) #add options to arguments like in other examples\n        display(NPT)\n        \n    Then, make sure in the Final_Widget options for plot_type, you add the string 'new plot type name' to the list.\n    \n    The commentin
# ...

# %%
#ideas and things to do: 
#      add in more dataset options    
#      ensure log scales appear for the necessary constituents
#      add an option to select the dpi resolution of the save file
#      add an option for fontsize/labelsize of plots
#      add an option to select the order of the datasets
#      add an option to choose gs.update(wspace = ?) and gs.update(hspace = ?) - gap distance between plots
#      find out how to embed in a website and connect to datasets (see below)
#      get widgets to appear horizontally rather than vertical?
#      design a function for naming individual xlabels so you don't have to copy and paste loads of code
#      make code more efficient/reasonable/improve comments

"""
embed in a website:
    At the top of Jupyter Notebook there is a widget option. 
    Select this and select embed widget.
    Try this out in a HTML file?
    Google around to see how this can be done smoothly.
    Would be awesome to have interactive tools on websites.
    Would be great to have interactive tools linked when posting on Twitter about a new paper/new results/start a science conversation.
"""
# Out:
# '\nembed in a website:\n    At the top of Jupyter Notebook there is a widget option. \n    Select this and select embed widget.\n    Try this out in a HTML file?\n    Google around to see how this can be done smoothly.\n    Would be awesome to have interactive tools on websites.\n    Would be great to have interactive tools linked when posting on Twitter about a new paper/new results/start a science conversation.\n'

# %%
#imports
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from ipywidgets import interactive
import matplotlib.gridspec as gridspec

# %%
import matplotlib.cm as cm
#use gradients from colourmaps
#Blues
blues = cm.get_cmap('Blues')
darkblue = blues(0.8)
blue = blues(0.6)
lightblue = blues(0.4)

#Reds
reds = cm.get_cmap('Reds')
darkred = reds(0.8)
red = reds(0.6)
lightred = reds(0.4)

# now assign colours for each dataset
color1 = 'k'; color2 = 'blue'; color3 = 'red'; color4 = 'magenta'; color5 = 'green'
color6 = 'k'; color7 = 'blue'; color8 = 'red'; color9 = 'magenta'

# %%
# read in files
"""
So far, this has been set up to analyse .cam files from WACCM output data
"""

"""
h0 file (or a file with gw variable)
make sure this file has gw variable in order to produce latitudinal weights
"""

archive_dir_h0 = 'insert path here' #path to directory
run_h0 = 'insert file name here' #filename
ds_h0 = xr.open_dataset(archive_dir_h0+run_h0) #open dataset

#assign gaussian weights
gw = ds_h0.gw.values # define guassian weights

"""
Dataset 1
"""
archive_dir1 = 'insert path here' #path to directory
run1 = 'insert file name here' #filename
ds1 = xr.open_dataset(archive_dir1+run1) #open dataset
nlon1 = ds1['lon'].size #longitude datset size
nlev1 = ds1['lev'].size #level datset size
ds1_name = 'DS1'

"""
Dataset 2
"""
archive_dir2 = 'insert path here' #path to directory
run2 = 'insert file name here' #filename
ds2 = xr.open_dataset(archive_dir2+run2) #open dataset
nlon2 = ds2['lon'].size #longitude datset size
nlev2 = ds2['lev'].size #level datset size
ds2_name = 'DS2'

"""
Dataset 3
"""
archive_dir3 = 'insert path here' #path to directory
run3 = 'insert file name here' #filename
ds3 = xr.open_dataset(archive_dir3+run3) #open dataset
nlon3 = ds3['lon'].size #longitude datset size
nlev3 = ds3['lev'].size #level datset size
ds3_name = 'DS3'

"""
Dataset 4
"""
archive_dir4 = 'insert path here' #path to directory
run4 = 'insert file name here' #filename
ds4 = xr.open_dataset(archive_dir4+run4) #open dataset
nlon4 = ds4['lon'].size #longitude datset size
nlev4 = ds4['lev'].size #level datset size
ds4_name = 'DS4'

"""
Dataset 5
"""
archive_dir5 = 'insert path here' #path to directory
run5 = 'insert file name here' #filename
ds5 = xr.open_dataset(archive_dir5+run5)
nlon5 = ds5['lon'].size #longitude datset size
nlev5 = ds5['lev'].size #level datset size
ds5_name = 'DS5'

"""
Dataset 6
"""
archive_dir6 = 'insert path here' #path to directory
run6 = 'insert file name here' #filename
ds6 = xr.open_dataset(archive_dir6+run6)
nlon6 = ds6['lon'].size #longitude datset size
nlev6 = ds6['lev'].size #level datset size
ds6_name = 'DS6'

"""
Dataset 7
"""
archive_dir7 = 'insert path here' #path to directory
run7 = 'insert file name here' #filename
ds7 = xr.open_dataset(archive_dir7+run7)
nlon7 = ds7['lon'].size #longitude datset size
nlev7 = ds7['lev'].size #level datset size
ds7_name = 'DS7'

"""
Dataset 8
"""
archive_dir8 = 'insert path here' #path to directory
run8 = 'insert file name here' #filename
ds8 = xr.open_dataset(archive_dir8+run8)
nlon8 = ds8['lon'].size #longitude datset size
nlev8 = ds8['lev'].size #level datset size
ds8_name = 'DS8'

"""
Dataset 9
"""
archive_dir9 = 'insert path here' #path to directory
run9 = 'insert file name here' #filename
ds9 = xr.open_dataset(archive_dir9+run9)
nlon9 = ds9['lon'].size #longitude datset size
nlev9 = ds9['lev'].size #level datset size
ds9_name = 'DS9'

"""
Can add in aditional datasets if you wish, but then functions will need to be altered accordingly
"""
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     194             try:
# --> 195                 file = self._cache[self._key]
#     196             except KeyError:
#
# ~/anaconda3/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      42         with self._lock:
# ---> 43             value = self._cache[key]
#      44             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/nobackup/pygjc/cesm2/archive/b.e21.BWma1850.f19_g17.baseline/atm/hist/b.e21.BWma1850.f19_g17.baseline.cam.h0.0014-01.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# return subscript number or text as a string
def sub(Input):
    return r'$_{'+str(Input)+'}$'

# return superscript number or text as a string
def sup(Input):
    return r'$^{'+str(Input)+'}$'

"""
Function to return field label for x and y axes or colourbar plot with ease
Chemical mixing ratios are handled in the first line of the function,
then special cases afterwards
If something isn't in here, then you can add it at the bottom
"""
def field_labels(field):
    label = ''
    if (field != 'T'): label = field+' mixing ratio'
    if (field == 'T'): label = 'Temperature [K]'
    if (field == 'U'): label ='Zonal wind speed [ms'+sup(-1)+']'
    if (field == 'V'): label = 'Meridional wind speed [ms'+sup(-1)+']'   
    if (field == 'FDL'): label = 'Longwave downward flux [Wm'+r'$^{-2}$'+']'
    if (field == 'FDLC'): label = 'Longwave downward flux (clear-sky) [Wm'+r'$^{-2}$'+']'   
    if (field == 'FDS'): label = 'Shortwave downward flux [Wm'+r'$^{-2}$'+']'
    if (field == 'FDSC'): label = 'Shortwave downward flux (clear-sky) [Wm'+r'$^{-2}$'+']'
    if (field == 'FSDS'): label = 'Downwelling solar flux at surface [Wm'+r'$^{-2}$'+']'
    if (field == 'FSDSC'): label = 'Clearsky downwelling solar flux at surface [Wm'+r'$^{-2}$'+']'
    if (field == 'FSNS'): label = 'Net solar flux at surface [Wm'+r'$^{-2}$'+']'
    if (field == 'FSNSC'): label = 'Clearsky net solar flux at surface [Wm'+r'$^{-2}$'+']'
    if (field == 'FSNT'): label = 'Net solar flux at top of model [Wm'+r'$^{-2}$'+']'
    if (field == 'FSNTC'): label = 'Clearsky net solar flux at top of model [Wm'+r'$^{-2}$'+']'
    if (field == 'FSNTOA'): label = 'Net solar flux at top of atmosphere [Wm'+r'$^{-2}$'+']'
    if (field == 'FSNTOAC'): label = 'Clearsky net solar flux at top of atmosphere [Wm'+r'$^{-2}$'+']'
    if (field == 'FSUTOA'): label = 'Upwelling solar flux at top of atmosphere [Wm'+r'$^{-2}$'+']'  
    if (field == 'FLDS'): label = 'Downwelling longwave flux at surface [Wm'+r'$^{-2}$'+']'
    if (field == 'FLNS'): label = 'Net longwave flux at surface [Wm'+r'$^{-2}$'+']'
    if (field == 'FLNSC'): label = 'Clearsky net longwave flux at surface [Wm'+r'$^{-2}$'+']'
    if (field == 'FLNT'): label = 'Net longwave flux at top of model [Wm'+r'$^{-2}$'+']'
    if (field == 'FLNTC'): label = 'Clearsky net longwave flux at top of model [Wm'+r'$^{-2}$'+']'
    if (field == 'FLUT'): label = 'Upwelling longwave flux at top of model [Wm'+r'$^{-2}$'+']'
    if (field == 'FLUTC'): label = 'Clearsky upwelling longwave flux at top of model [Wm'+r'$^{-2}$'+']'
    if (field == 'IWC'): label = 'Ice water content mixing ratio'
    if (field == 'CLDLIQ'): label = 'Cloud fraction (liquid)'
    if (field == 'CLDICE'): label = 'Cloud fraction (ice)'
    if (field == 'TROP_Z'): label = 'Tropopause height [m]'
    if (field == 'TROP_P'): label = 'Tropopause pressure [hPa]'
    if (field == 'TROP_T'): label = 'Tropopause temperature [K]'
    if (field == 'QRL'): label = 'Longwave heating rate (clearsky) [Ks'+sup(-1)+']' 
    if (field == 'QRS'): label = 'Solar heating rate [Ks'+sup(-1)+']'
    if (field == 'QRSC'): label = 'Solar heating rate (clearsky) [Ks'+sup(-1)+']'
    if (field == 'QRLC'): label = 'Longwave heating rate (clearsky) [Ks'+sup(-1)+']'
    return label
    """
    add extra fields:
    if (field == ''): label = ''
    """

# %%
#cmap list
cmaps = ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r',
         'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 
         'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 
         'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 
         'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 
         'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 
         'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 
         'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r',
         'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 
         'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r',
         'terrain', 'terrain_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r']

# %%
def Store_values(var1 = True, var2 = False, var3 = False, var4 = False, var5 = False, 
           var6 = False, var7 = False, var8 = False, var9 = False, plot_num = 1):
    Values = np.array([var1.max(), var1.min()])
    if (plot_num == 2):
        Values = np.array([var1.max(), var1.min(), var2.max(), var2.min()])
    if (plot_num == 3):
        Values = np.array([var1.max(), var1.min(), var2.max(), var2.min(), var3.max(), var3.min()])
    if (plot_num == 4):
        Values = np.array([var1.max(), var1.min(), var2.max(), var2.min(), var3.max(), var3.min(),
                           var4.max(), var4.min()])
    if (plot_num == 5):
        Values = np.array([var1.max(), var1.min(), var2.max(), var2.min(), var3.max(), var3.min(),
                           var4.max(), var4.min(), var5.max(), var5.min()])
    if (plot_num == 6):
        Values = np.array([var1.max(), var1.min(), var2.max(), var2.min(), var3.max(), var3.min(),
                           var4.max(), var4.min(), var5.max(), var5.min(),var6.max(), var6.min()])
    if (plot_num == 7):
        Values = np.array([var1.max(), var1.min(), var2.max(), var2.min(), var3.max(), var3.min(),
                           var4.max(), var4.min(), var5.max(), var5.min(),var6.max(), var6.min(),
                           var7.max(), var7.min()])
    if (plot_num == 8):
        Values = np.array([var1.max(), var1.min(), var2.max(), var2.min(), var3.max(), var3.min(),
                           var4.max(), var4.min(), var5.max(), var5.min(),var6.max(), var6.min(),
                           var7.max(), var7.min(), var8.max(), var8.min()])
    if (plot_num == 9):
        Values = np.array([var1.max(), var1.min(), var2.max(), var2.min(), var3.max(), var3.min(),
                           var4.max(), var4.min(), var5.max(), var5.min(),var6.max(), var6.min(),
                           var7.max(), var7.min(), var8.max(), var8.min(), var9.max(), var9.min()])
        
    if (Values.min() < 0 and Values.max() > 0 and abs(Values.max()) > abs(Values.min())):
        Values = np.append(Values, -Values.max())
    if (Values.min() < 0 and Values.max() > 0 and abs(Values.max()) < abs(Values.min())):
        Values = np.append(Values, -Values.min())
    return Values

# %%
# compute latitudinally weighted dataset from any 3D variable 
def LWAV(DS, time = False):
    try:
        DS = DS.mean(dim='lon')
    except:
        print('')
    if (time == False):
        try:
            DS = DS.mean(dim='time')
        except:
            print('')
    DS = gw*DS #multiply by gaussian weights
    try:
        DS = np.sum(DS,axis=1)/gw.sum() #weighted mean
    except:
        DS = np.sum(DS,axis=0)/gw.sum() #weighted mean 
    return DS #return a numpy array that has been modified above

# %%
#Zonal mean plots: function definitions
def Zonal_Mean_Plot(plot_num = 1, logtop=-4, field = 'T', cmap = 'Blues',
                    fig_width = 7, fig_height = 4, Contours = False, Levels = 5, save = False):
    
    #format for contours
    fmt = '%r '
    if(field == 'T'):
        fmt = '%r K' 
    if(field == 'U' or field == 'V'):
        fmt = '%r ms'+sup(-1) 
    
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
    gs = gridspec.GridSpec(1, 1) #1 column
    
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        #sort out subplots
        if (plot_num == 2):
            gs = gridspec.GridSpec(1, 2) #2 columns
        if (plot_num == 3):
            gs = gridspec.GridSpec(1, 3) #3 columns
        if (plot_num >= 4 and plot_num <= 6):
            gs = gridspec.GridSpec(2, 3) #2 rows 3 columns
            gs.update(hspace = 0.3)
        if (plot_num >= 7 and plot_num <= 9):
            gs = gridspec.GridSpec(3, 3) #3 rows 3 columns
            gs.update(hspace = 0.3)

        plt.subplot(gs[0, 0])
        a = var1.mean(dim='lon')
        model = a.where(ds1.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
        ax = plt.gca()
        ax.set_ylim([1000,10**logtop])
        ax.set_yscale('log')
        ax.set_ylabel('Pressure (hPa)', fontsize = 15)
        plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
        plt.title(ds1_name, fontsize = 15)
        plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
        if (Contours == True): #set up contours
            x = a.lat.values; y = a.lev.values; z = a.values
            CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
            plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours            

        if (plot_num >= 2):
            plt.subplot(gs[0, 1])
            a = var1.mean(dim='lon')
            a.where(ds1.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds2_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            if (Contours == True): #set up contours
                x = a.lat.values; y = a.lev.values; z = a.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 3):
            plt.subplot(gs[0, 2])
            a = var3.mean(dim='lon')
            a.where(ds3.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds3_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            if (Contours == True): #set up contours
                x = a.lat.values; y = a.lev.values; z = a.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 4):
            plt.subplot(gs[1, 0])
            a = var4.mean(dim='lon')
            a.where(ds4.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.ylabel('Pressure [hPa]', fontsize = 15)
            plt.title(ds4_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
            if (Contours == True): #set up contours
                x = a.lat.values; y = a.lev.values; z = a.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 5):
            plt.subplot(gs[1, 1])
            a = var5.mean(dim='lon')
            a.where(ds5.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds5_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            if (Contours == True): #set up contours
                x = a.lat.values; y = a.lev.values; z = a.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 6):
            plt.subplot(gs[1, 2])
            a = var6.mean(dim='lon')
            a.where(ds6.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds6_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            if (Contours == True): #set up contours
                x = a.lat.values; y = a.lev.values; z = a.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 7):
            plt.subplot(gs[2, 0])
            a = var7.mean(dim='lon')
            a.where(ds7.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.ylabel('Pressure [hPa]', fontsize = 15)
            plt.title(ds7_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
            if (Contours == True): #set up contours
                x = a.lat.values; y = a.lev.values; z = a.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 8):
            plt.subplot(gs[2, 1])
            a = var8.mean(dim='lon')
            a.where(ds8.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds8_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            if (Contours == True): #set up contours
                x = a.lat.values; y = a.lev.values; z = a.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 9):
            plt.subplot(gs[2, 2])
            a = var9.mean(dim='lon')
            a.where(ds9.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds9_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            if (Contours == True): #set up contours
                x = a.lat.values; y = a.lev.values; z = a.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        #add colourbar   
        cax = Figure.add_axes([0.94,0.125,0.02,0.755])
        cbar = plt.colorbar(model, cax=cax)
        cbar.set_label(field_labels(field = field),size=15)
        cbar.ax.tick_params(labelsize=15) 
        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return

def Zonal_Mean_Difference_plot(Dataset1 = 1, Dataset2 = 2, logtop=-4, field = 'T', cmap = 'Blues',
                   fig_width = 7, fig_height = 4, percentage = False, Contours = False, Levels = 5, save = False):
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
    
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        Difference = var1 - var2; Title = ds1_name+' - '+ds2_name
        if (percentage == False):
            # 1st DS
            if (Dataset1 == 'DS1' and Dataset2 == 'DS2'): Difference = var1 - var2; Title = ds1_name+' - '+ds2_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS3'): Difference = var1 - var3; Title = ds1_name+' - '+ds3_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS4'): Difference = var1 - var4; Title = ds1_name+' - '+ds4_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS5'): Difference = var1 - var5; Title = ds1_name+' - '+ds5_name
            # 2nd DS
            if (Dataset1 == 'DS2' and Dataset2 == 'DS3'): Difference = var2 - var3; Title = ds2_name+' - '+ds3_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS1'): Difference = var2 - var1; Title = ds2_name+' - '+ds1_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS4'): Difference = var2 - var4; Title = ds2_name+' - '+ds4_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS5'): Difference = var2 - var5; Title = ds2_name+' - '+ds5_name 
            # 3rd DS
            if (Dataset1 == 'DS3' and Dataset2 == 'DS2'): Difference = var3 - var2; Title = ds3_name+' - '+ds2_name  
            if (Dataset1 == 'DS3' and Dataset2 == 'DS1'): Difference = var3 - var1; Title = ds3_name+' - '+ds1_name
            if (Dataset1 == 'DS3' and Dataset2 == 'DS4'): Difference = var3 - var4; Title = ds3_name+' - '+ds4_name  
            if (Dataset1 == 'DS3' and Dataset2 == 'DS5'): Difference = var3 - var5; Title = ds3_name+' - '+ds5_name
            # 4th DS
            if (Dataset1 == 'DS4' and Dataset2 == 'DS2'): Difference = var4 - var2; Title = ds4_name+' - '+ds2_name  
            if (Dataset1 == 'DS4' and Dataset2 == 'DS1'): Difference = var4 - var1; Title = ds4_name+' - '+ds1_name
            if (Dataset1 == 'DS4' and Dataset2 == 'DS3'): Difference = var4 - var3; Title = ds4_name+' - '+ds3_name  
            if (Dataset1 == 'DS4' and Dataset2 == 'DS5'): Difference = var4 - var5; Title = ds4_name+' - '+ds5_name
            # 5th DS
            if (Dataset1 == 'DS5' and Dataset2 == 'DS2'): Difference = var5 - var2; Title = ds5_name+' - '+ds2_name  
            if (Dataset1 == 'DS5' and Dataset2 == 'DS1'): Difference = var5 - var1; Title = ds5_name+' - '+ds1_name
            if (Dataset1 == 'DS5' and Dataset2 == 'DS4'): Difference = var5 - var4; Title = ds5_name+' - '+ds4_name  
            if (Dataset1 == 'DS5' and Dataset2 == 'DS3'): Difference = var5 - var5; Title = ds5_name+' - '+ds3_name
        if (percentage == True):
            # 1st DS
            if (Dataset1 == 'DS1' and Dataset2 == 'DS2'): Difference = 100*(var1 - var2)/var1; Title = ds1_name+' - '+ds2_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS3'): Difference = 100*(var1 - var3)/var1; Title = ds1_name+' - '+ds3_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS4'): Difference = 100*(var1 - var4)/var1; Title = ds1_name+' - '+ds4_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS5'): Difference = 100*(var1 - var5)/var1; Title = ds1_name+' - '+ds5_name+' %'
            # 2nd DS
            if (Dataset1 == 'DS2' and Dataset2 == 'DS3'): Difference = 100*(var2 - var3)/var2; Title = ds2_name+' - '+ds3_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS1'): Difference = 100*(var2 - var1)/var2; Title = ds2_name+' - '+ds1_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS4'): Difference = 100*(var2 - var4)/var2; Title = ds2_name+' - '+ds4_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS5'): Difference = 100*(var2 - var5)/var2; Title = ds2_name+' - '+ds5_name +' %'
            # 3rd DS
            if (Dataset1 == 'DS3' and Dataset2 == 'DS2'): Difference = 100*(var3 - var2)/var3; Title = ds3_name+' - '+ds2_name +' %' 
            if (Dataset1 == 'DS3' and Dataset2 == 'DS1'): Difference = 100*(var3 - var1)/var3; Title = ds3_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS3' and Dataset2 == 'DS4'): Difference = 100*(var3 - var4)/var3; Title = ds3_name+' - '+ds4_name +' %' 
            if (Dataset1 == 'DS3' and Dataset2 == 'DS5'): Difference = 100*(var3 - var5)/var3; Title = ds3_name+' - '+ds5_name+' %'
            # 4th DS
            if (Dataset1 == 'DS4' and Dataset2 == 'DS2'): Difference = 100*(var4 - var2)/var4; Title = ds4_name+' - '+ds2_name  +' %'
            if (Dataset1 == 'DS4' and Dataset2 == 'DS1'): Difference = 100*(var4 - var1)/var4; Title = ds4_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS4' and Dataset2 == 'DS3'): Difference = 100*(var4 - var3)/var4; Title = ds4_name+' - '+ds3_name +' %' 
            if (Dataset1 == 'DS4' and Dataset2 == 'DS5'): Difference = 100*(var4 - var5)/var4; Title = ds4_name+' - '+ds5_name+' %'
            # 5th DS
            if (Dataset1 == 'DS5' and Dataset2 == 'DS2'): Difference = 100*(var5 - var2)/var5; Title = ds5_name+' - '+ds2_name  +' %'
            if (Dataset1 == 'DS5' and Dataset2 == 'DS1'): Difference = 100*(var5 - var1)/var5; Title = ds5_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS5' and Dataset2 == 'DS4'): Difference = 100*(var5 - var4)/var5; Title = ds5_name+' - '+ds4_name +' %' 
            if (Dataset1 == 'DS5' and Dataset2 == 'DS3'): Difference = 100*(var5 - var5)/var5; Title = ds5_name+' - '+ds3_name+' %'
        
        a = Difference.mean(dim='lon')
        model = a.where(ds1.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
        ax = plt.gca()
        ax.set_ylim([1000,10**logtop])
        ax.set_yscale('log')
        ax.set_ylabel('Pressure (hPa)', fontsize = 15)
        plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
        plt.title(Title, fontsize = 15)
        plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
        if (Contours == True): #set up contours
            x = a.lat.values; y = a.lev.values; z = a.values
            CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
            plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        
        #add colourbar   
        cax = Figure.add_axes([0.94,0.125,0.02,0.755])
        cbar = plt.colorbar(model, cax=cax)
        cbar.set_label(field_labels(field = field),size=15)
        cbar.ax.tick_params(labelsize=15) 
        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return

# %%
#2D field plot
def Two_D_Plot(plot_num = 1, field = 'T', cmap = 'Blues', fig_width = 7, fig_height = 4,
               Contours = False, Levels = 5, save = False):
    #format for contours
    fmt = '%r '
    if(field == 'T'):
        fmt = '%r K' 
    if(field == 'U' or field == 'V'):
        fmt = '%r ms'+sup(-1) 
    
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
    gs = gridspec.GridSpec(1, 1) #1 column
    
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    if (var1.dims == ('time', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        Values = Store_values(var1 = var1, var2 = var2, var3 = var3, var4 = var4, var5 = var5,
                    var6 = var6, var7 = var7, var8 = var8, var9 = var9, plot_num = plot_num)
            
        #sort out subplots
        if (plot_num == 2):
            gs = gridspec.GridSpec(1, 2) #2 columns
        if (plot_num == 3):
            gs = gridspec.GridSpec(1, 3) #3 columns
        if (plot_num >= 4 and plot_num <= 6):
            gs = gridspec.GridSpec(2, 3) #2 rows 3 columns
            gs.update(hspace = 0.3)
        if (plot_num >= 7 and plot_num <= 9):
            gs = gridspec.GridSpec(3, 3) #3 rows 3 columns
            gs.update(hspace = 0.3)

        plt.subplot(gs[0, 0])
        model = var1.plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False, vmax = Values.max(), vmin = Values.min())
        plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
        plt.ylabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
        plt.xlim(0,360); plt.xticks(np.arange(0, 420, 60))
        plt.ylim(-90,90); plt.yticks(np.arange(-90, 120, 30))
        plt.title(ds1_name, fontsize = 15)
        plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
        if (Contours == True): #set up contours
            x = var1.lon.values; y = var1.lat.values; z = var1.values
            CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
            plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours            

        if (plot_num >= 2):
            plt.subplot(gs[0, 1])
            model = var2.plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False, vmax = Values.max(), vmin = Values.min())
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.xlim(0,360); plt.xticks(np.arange(0, 420, 60))
            plt.ylim(-90,90); plt.yticks(np.arange(-90, 120, 30))
            plt.title(ds2_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            if (Contours == True): #set up contours
                x = var2.lon.values; y = var2.lat.values; z = var2.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 3):
            plt.subplot(gs[0, 2])
            model = var3.plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False, vmax = Values.max(), vmin = Values.min())
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.xlim(0,360); plt.xticks(np.arange(0, 420, 60))
            plt.ylim(-90,90); plt.yticks(np.arange(-90, 120, 30))
            plt.title(ds3_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            if (Contours == True): #set up contours
                x = var3.lon.values; y = var3.lat.values; z = var3.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 4):
            plt.subplot(gs[1, 0])
            model = var4.plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False, vmax = Values.max(), vmin = Values.min())
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.ylabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.xlim(0,360); plt.xticks(np.arange(0, 420, 60))
            plt.ylim(-90,90); plt.yticks(np.arange(-90, 120, 30))
            plt.title(ds4_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
            if (Contours == True): #set up contours
                x = var4.lon.values; y = var4.lat.values; z = var4.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        if (plot_num >= 5):
            plt.subplot(gs[1, 1])
            model = var5.plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False, vmax = Values.max(), vmin = Values.min())
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.xlim(0,360); plt.xticks(np.arange(0, 420, 60))
            plt.ylim(-90,90); plt.yticks(np.arange(-90, 120, 30))
            plt.title(ds5_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            if (Contours == True): #set up contours
                x = var5.lon.values; y = var5.lat.values; z = var5.values
                CS = plt.contour(x,y,z,Levels,linewidths=2,colors='k')#set the contours
                plt.clabel(CS,CS.levels, inline=1, fmt=fmt, fontsize=12)#label the contours
        #add colourbar   
        cax = Figure.add_axes([0.94,0.125,0.02,0.755])
        cbar = plt.colorbar(model, cax=cax)
        cbar.set_label(field_labels(field = field),size=15)
        
        cbar.ax.tick_params(labelsize=15) 
        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return

# %%
#Vertical profile plots: function definitions
def Vertical_Profile_Plot(same_plot = [True, False], plot_num = 1, logtop=-4, field = 'T',
                          fig_width = 7, fig_height = 4, xscale = 'log', save = False):
    
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
    gs = gridspec.GridSpec(1, 1) #1 column
            
    #asign variable from datasets 
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        if (same_plot == False):

            #sort out subplots
            if (plot_num == 2):
                gs = gridspec.GridSpec(1, 2) #2 columns
            if (plot_num == 3):
                gs = gridspec.GridSpec(1, 3) #3 columns
            if (plot_num >= 4 and plot_num <= 6):
                gs = gridspec.GridSpec(2, 3) #2 rows 3 columns
                gs.update(hspace = 0.3)
            if (plot_num >= 7 and plot_num <= 9):
                gs = gridspec.GridSpec(3, 3) #3 rows 3 columns
                gs.update(hspace = 0.3)

            plt.subplot(gs[0, 0])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            if (xscale == 'Linear'): ax.set_xscale('linear')
            if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
            ax.set_ylabel('Pressure (hPa)', fontsize = 15)
            ax.set_xlabel(field+' mixing ratio', fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, width = 2)
            plt.title(ds1_name, fontsize = 15)
            if (field=='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')

            if (plot_num >= 2):
                plt.subplot(gs[0, 1])
                plt.plot(LWAV(var2),ds2.lev.values, lw = 2, color = color2)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(field+' mixing ratio', fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds2_name, fontsize = 15)
                if (field=='T'):
                    ax.set_xlabel('Temperature [K]', fontsize = 15)
                    ax.set_xscale('linear')

            if (plot_num >= 3):                
                plt.subplot(gs[0, 2]) 
                plt.plot(LWAV(var3),ds3.lev.values, lw = 2, color = color3)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(field+' mixing ratio', fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds3_name, fontsize = 15)
                if (field=='T'):
                    ax.set_xlabel('Temperature [K]', fontsize = 15)
                    ax.set_xscale('linear')
            
            if (plot_num >= 4):                
                plt.subplot(gs[1, 0])
                plt.plot(LWAV(var4),ds4.lev.values, lw = 2, color = color4)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(field+' mixing ratio', fontsize = 15)
                ax.set_ylabel('Pressure (hPa)', fontsize = 15)
                plt.tick_params(labelsize = 15, right = True, length = 4, width = 2)
                plt.title(ds4_name, fontsize = 15)
                if (field=='T'):
                    ax.set_xlabel('Temperature [K]', fontsize = 15)
                    ax.set_xscale('linear')
            
            if (plot_num >= 5):                
                plt.subplot(gs[1, 1])
                plt.plot(LWAV(var5),ds5.lev.values, lw = 2, color = color5)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(field+' mixing ratio', fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds5_name, fontsize = 15)
                if (field=='T'):
                    ax.set_xlabel('Temperature [K]', fontsize = 15)
                    ax.set_xscale('linear')
                    
            if (plot_num >= 6):                
                plt.subplot(gs[1, 2])
                plt.plot(LWAV(var6),ds6.lev.values, lw = 2, color = color6)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(field_labels(field = field), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds6_name, fontsize = 15)
                if (field=='T'):
                    ax.set_xlabel('Temperature [K]', fontsize = 15)
                    ax.set_xscale('linear')
                    
            if (plot_num >= 7):                
                plt.subplot(gs[2, 0])
                plt.plot(LWAV(var7),ds7.lev.values, lw = 2, color = color7)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_ylabel('Pressure (hPa)', fontsize = 15)
                ax.set_xlabel(field_labels(field = field), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = True, right = True, length = 4, width = 2)
                plt.title(ds7_name, fontsize = 15)
                if (field=='T'):
                    ax.set_xlabel('Temperature [K]', fontsize = 15)
                    ax.set_xscale('linear')
                    
            if (plot_num >= 8):                
                plt.subplot(gs[2, 1])
                plt.plot(LWAV(var8),ds8.lev.values, lw = 2, color = color8)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(field_labels(field = field), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds8_name, fontsize = 15)
                if (field=='T'):
                    ax.set_xlabel('Temperature [K]', fontsize = 15)
                    ax.set_xscale('linear')
                    
            if (plot_num >= 9):                
                plt.subplot(gs[2, 2])
                plt.plot(LWAV(var9),ds9.lev.values, lw = 2, color = color9)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(field_labels(field = field), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds9_name, fontsize = 15)
                if (field=='T'):
                    ax.set_xlabel('Temperature [K]', fontsize = 15)
                    ax.set_xscale('linear')

        #plot global mean vertical profile of chemical mixing ratio/temperature on same plots
        elif (same_plot == True):
            plt.subplot(gs[0, 0])
            plt.plot(LWAV(var1),ds1.lev.values, color = color1, lw = 2, label = ds1_name)
            if (plot_num >= 2):
                plt.plot(LWAV(var2),ds2.lev.values, color = color2, lw = 2, label = ds2_name)
            if (plot_num >= 3):
                plt.plot(LWAV(var3),ds3.lev.values, color = color3, lw = 2, label = ds3_name)
            if (plot_num >= 4):
                plt.plot(LWAV(var4),ds4.lev.values, color = color4, lw = 2, label = ds4_name)
            if (plot_num >= 5):
                plt.plot(LWAV(var5),ds5.lev.values, color = color5, lw = 2, label = ds5_name)
            if (plot_num >= 6):
                plt.plot(LWAV(var6),ds6.lev.values, color = color6, lw = 2, label = ds6_name)
            if (plot_num >= 7):
                plt.plot(LWAV(var7),ds7.lev.values, color = color7, lw = 2, label = ds7_name)
            if (plot_num >= 8):
                plt.plot(LWAV(var8),ds8.lev.values, color = color8, lw = 2, label = ds8_name)
            if (plot_num >= 9):
                plt.plot(LWAV(var9),ds9.lev.values, color = color9, lw = 2, label = ds9_name)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            if (xscale == 'Linear'): ax.set_xscale('linear')
            if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
            ax.set_ylabel('Pressure (hPa)', fontsize = 15)
            ax.set_xlabel(field_labels(field = field), fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, width = 2)
            plt.legend(loc = 0, frameon = False, fontsize = 15)
            if (field=='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return   

def Vertical_Profile_Difference_Plot(Dataset1 = 1, Dataset2 = 2, logtop=-4, field = 'T',
                          fig_width = 7, fig_height = 4, percentage = False, save = False):
    
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
                        
    #asign variable from datasets 
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        Difference = var1 - var2; Title = ds1_name+' - '+ds2_name
        if (percentage == False):
            # 1st DS
            if (Dataset1 == 'DS1' and Dataset2 == 'DS2'): Difference = var1 - var2; Title = ds1_name+' - '+ds2_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS3'): Difference = var1 - var3; Title = ds1_name+' - '+ds3_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS4'): Difference = var1 - var4; Title = ds1_name+' - '+ds4_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS5'): Difference = var1 - var5; Title = ds1_name+' - '+ds5_name
            # 2nd DS
            if (Dataset1 == 'DS2' and Dataset2 == 'DS3'): Difference = var2 - var3; Title = ds2_name+' - '+ds3_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS1'): Difference = var2 - var1; Title = ds2_name+' - '+ds1_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS4'): Difference = var2 - var4; Title = ds2_name+' - '+ds4_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS5'): Difference = var2 - var5; Title = ds2_name+' - '+ds5_name 
            # 3rd DS
            if (Dataset1 == 'DS3' and Dataset2 == 'DS2'): Difference = var3 - var2; Title = ds3_name+' - '+ds2_name  
            if (Dataset1 == 'DS3' and Dataset2 == 'DS1'): Difference = var3 - var1; Title = ds3_name+' - '+ds1_name
            if (Dataset1 == 'DS3' and Dataset2 == 'DS4'): Difference = var3 - var4; Title = ds3_name+' - '+ds4_name  
            if (Dataset1 == 'DS3' and Dataset2 == 'DS5'): Difference = var3 - var5; Title = ds3_name+' - '+ds5_name
            # 4th DS
            if (Dataset1 == 'DS4' and Dataset2 == 'DS2'): Difference = var4 - var2; Title = ds4_name+' - '+ds2_name  
            if (Dataset1 == 'DS4' and Dataset2 == 'DS1'): Difference = var4 - var1; Title = ds4_name+' - '+ds1_name
            if (Dataset1 == 'DS4' and Dataset2 == 'DS3'): Difference = var4 - var3; Title = ds4_name+' - '+ds3_name  
            if (Dataset1 == 'DS4' and Dataset2 == 'DS5'): Difference = var4 - var5; Title = ds4_name+' - '+ds5_name
            # 5th DS
            if (Dataset1 == 'DS5' and Dataset2 == 'DS2'): Difference = var5 - var2; Title = ds5_name+' - '+ds2_name  
            if (Dataset1 == 'DS5' and Dataset2 == 'DS1'): Difference = var5 - var1; Title = ds5_name+' - '+ds1_name
            if (Dataset1 == 'DS5' and Dataset2 == 'DS4'): Difference = var5 - var4; Title = ds5_name+' - '+ds4_name  
            if (Dataset1 == 'DS5' and Dataset2 == 'DS3'): Difference = var5 - var5; Title = ds5_name+' - '+ds3_name
        if (percentage == True):
            # 1st DS
            if (Dataset1 == 'DS1' and Dataset2 == 'DS2'): Difference = 100*(var1 - var2)/var1; Title = ds1_name+' - '+ds2_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS3'): Difference = 100*(var1 - var3)/var1; Title = ds1_name+' - '+ds3_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS4'): Difference = 100*(var1 - var4)/var1; Title = ds1_name+' - '+ds4_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS5'): Difference = 100*(var1 - var5)/var1; Title = ds1_name+' - '+ds5_name+' %'
            # 2nd DS
            if (Dataset1 == 'DS2' and Dataset2 == 'DS3'): Difference = 100*(var2 - var3)/var2; Title = ds2_name+' - '+ds3_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS1'): Difference = 100*(var2 - var1)/var2; Title = ds2_name+' - '+ds1_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS4'): Difference = 100*(var2 - var4)/var2; Title = ds2_name+' - '+ds4_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS5'): Difference = 100*(var2 - var5)/var2; Title = ds2_name+' - '+ds5_name +' %'
            # 3rd DS
            if (Dataset1 == 'DS3' and Dataset2 == 'DS2'): Difference = 100*(var3 - var2)/var3; Title = ds3_name+' - '+ds2_name +' %' 
            if (Dataset1 == 'DS3' and Dataset2 == 'DS1'): Difference = 100*(var3 - var1)/var3; Title = ds3_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS3' and Dataset2 == 'DS4'): Difference = 100*(var3 - var4)/var3; Title = ds3_name+' - '+ds4_name +' %' 
            if (Dataset1 == 'DS3' and Dataset2 == 'DS5'): Difference = 100*(var3 - var5)/var3; Title = ds3_name+' - '+ds5_name+' %'
            # 4th DS
            if (Dataset1 == 'DS4' and Dataset2 == 'DS2'): Difference = 100*(var4 - var2)/var4; Title = ds4_name+' - '+ds2_name  +' %'
            if (Dataset1 == 'DS4' and Dataset2 == 'DS1'): Difference = 100*(var4 - var1)/var4; Title = ds4_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS4' and Dataset2 == 'DS3'): Difference = 100*(var4 - var3)/var4; Title = ds4_name+' - '+ds3_name +' %' 
            if (Dataset1 == 'DS4' and Dataset2 == 'DS5'): Difference = 100*(var4 - var5)/var4; Title = ds4_name+' - '+ds5_name+' %'
            # 5th DS
            if (Dataset1 == 'DS5' and Dataset2 == 'DS2'): Difference = 100*(var5 - var2)/var5; Title = ds5_name+' - '+ds2_name  +' %'
            if (Dataset1 == 'DS5' and Dataset2 == 'DS1'): Difference = 100*(var5 - var1)/var5; Title = ds5_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS5' and Dataset2 == 'DS4'): Difference = 100*(var5 - var4)/var5; Title = ds5_name+' - '+ds4_name +' %' 
            if (Dataset1 == 'DS5' and Dataset2 == 'DS3'): Difference = 100*(var5 - var5)/var5; Title = ds5_name+' - '+ds3_name+' %'
             
        plt.plot(LWAV(Difference),ds1.lev.values, lw = 2)
        ax = plt.gca()
        ax.set_ylim([1000,10**logtop])
        ax.set_yscale('log')
        ax.set_xscale('linear')
        ax.set_ylabel('Pressure (hPa)', fontsize = 15)
        if (percentage == False): ax.set_xlabel(field+' mixing ratio difference', fontsize = 15)
        if (percentage == True): ax.set_xlabel(field+' mixing ratio difference [%]', fontsize = 15)
        plt.tick_params(labelsize = 15, length = 4, width = 2)
        plt.title(Title, fontsize = 15)
        if (field=='T' and percentage == False):
            ax.set_xlabel('Temperature difference [K]', fontsize = 15)
            ax.set_xscale('linear')
        if (field=='T' and percentage == True):
            ax.set_xlabel('Temperature difference [%]', fontsize = 15)
            ax.set_xscale('linear')

        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return

# %%
def Add_Vars_Vertical(same_plot = [True, False], plot_num = 1, logtop=-4, fields = 2, field1 = 'T',
                      field2 = 'T',field3 = 'T',field4 = 'T',field5 = 'T',
                          fig_width = 7, fig_height = 4, xscale = 'log', save = False):
    
    def xlabels(plot_num = 2):
        label = field1 + ' + ' + field2
        if (plot_num == 3): label = field1 + ' + ' + field2 + ' + ' + field3
        if (plot_num == 4): label = field1 + ' + ' + field2 + ' + ' + field3 + ' + ' + field4
        if (plot_num == 5): label = field1 + ' + ' + field2 + ' + ' + field3 + ' + ' + field4 + ' + ' + field5 
        return label
    
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
    gs = gridspec.GridSpec(1, 1) #1 column
            
    #asign variable from datasets 
    var1 = ds1[field1]+ds1[field2]; var2 = ds2[field1]+ds2[field2]
    var3 = ds3[field1]+ds3[field2]; var4 = ds4[field1]+ds4[field2]
    var5 = ds5[field1]+ds5[field2]; var6 = ds6[field1]+ds6[field2]
    var7 = ds7[field1]+ds7[field2]; var8 = ds8[field1]+ds8[field2]
    var9 = ds9[field1]+ds9[field2]
    if (fields == 3):
        var1 = ds1[field1]+ds1[field2]+ds1[field3]; var2 = ds2[field1]+ds2[field2]+ds2[field3]
        var3 = ds3[field1]+ds3[field2]+ds3[field3]; var4 = ds4[field1]+ds4[field2]+ds4[field3]
        var5 = ds5[field1]+ds5[field2]+ds5[field3]; var6 = ds6[field1]+ds6[field2]+ds6[field3]
        var7 = ds7[field1]+ds7[field2]+ds7[field3]; var8 = ds8[field1]+ds8[field2]+ds8[field3]
        var9 = ds9[field1]+ds9[field2]+ds9[field3]
    if (fields == 4):
        var1 = ds1[field1]+ds1[field2]+ds1[field3]+ds1[field4]; var2 = ds2[field1]+ds2[field2]+ds2[field3]+ds2[field4]
        var3 = ds3[field1]+ds3[field2]+ds3[field3]+ds3[field4]; var4 = ds4[field1]+ds4[field2]+ds4[field3]+ds4[field4]
        var5 = ds5[field1]+ds5[field2]+ds5[field3]+ds5[field4]; var6 = ds6[field1]+ds6[field2]+ds6[field3]+ds6[field4]
        var7 = ds7[field1]+ds7[field2]+ds7[field3]+ds7[field4]; var8 = ds8[field1]+ds8[field2]+ds8[field3]+ds8[field4]
        var9 = ds9[field1]+ds9[field2]+ds9[field3]+ds9[field4]
    if (fields == 5):
        var1 = ds1[field1]+ds1[field2]+ds1[field3]+ds1[field4]+ds1[field5]; var2 = ds2[field1]+ds2[field2]+ds2[field3]+ds2[field4]+ds2[field5]
        var3 = ds3[field1]+ds3[field2]+ds3[field3]+ds3[field4]+ds3[field5]; var4 = ds4[field1]+ds4[field2]+ds4[field3]+ds4[field4]+ds4[field5]
        var5 = ds5[field1]+ds5[field2]+ds5[field3]+ds5[field4]+ds5[field5]; var6 = ds6[field1]+ds6[field2]+ds6[field3]+ds6[field4]+ds6[field5]
        var7 = ds7[field1]+ds7[field2]+ds7[field3]+ds7[field4]+ds7[field5]; var8 = ds8[field1]+ds8[field2]+ds8[field3]+ds8[field4]+ds8[field5]
        var9 = ds9[field1]+ds9[field2]+ds9[field3]+ds9[field4]+ds9[field5]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        if (same_plot == False):

            #sort out subplots
            if (plot_num == 2):
                gs = gridspec.GridSpec(1, 2) #2 columns
            if (plot_num == 3):
                gs = gridspec.GridSpec(1, 3) #3 columns
            if (plot_num >= 4 and plot_num <= 6):
                gs = gridspec.GridSpec(2, 3) #2 rows 3 columns
                gs.update(hspace = 0.3)
            if (plot_num >= 7 and plot_num <= 9):
                gs = gridspec.GridSpec(3, 3) #3 rows 3 columns
                gs.update(hspace = 0.3)

            plt.subplot(gs[0, 0])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            if (xscale == 'Linear'): ax.set_xscale('linear')
            if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
            ax.set_ylabel('Pressure (hPa)', fontsize = 15)
            ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, width = 2)
            plt.title(ds1_name, fontsize = 15)

            if (plot_num >= 2):
                plt.subplot(gs[0, 1])
                plt.plot(LWAV(var2),ds2.lev.values, lw = 2, color = color2)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds2_name, fontsize = 15)
                
            if (plot_num >= 3):                
                plt.subplot(gs[0, 2]) 
                plt.plot(LWAV(var3),ds3.lev.values, lw = 2, color = color3)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds3_name, fontsize = 15)
                            
            if (plot_num >= 4):                
                plt.subplot(gs[1, 0])
                plt.plot(LWAV(var4),ds4.lev.values, lw = 2, color = color4)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
                ax.set_ylabel('Pressure (hPa)', fontsize = 15)
                plt.tick_params(labelsize = 15, right = True, length = 4, width = 2)
                plt.title(ds4_name, fontsize = 15)
            
            if (plot_num >= 5):                
                plt.subplot(gs[1, 1])
                plt.plot(LWAV(var5),ds5.lev.values, lw = 2, color = color5)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds5_name, fontsize = 15)
            
            if (plot_num >= 6):                
                plt.subplot(gs[1, 2])
                plt.plot(LWAV(var6),ds6.lev.values, lw = 2, color = color6)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds6_name, fontsize = 15)
                    
            if (plot_num >= 7):                
                plt.subplot(gs[2, 0])
                plt.plot(LWAV(var7),ds7.lev.values, lw = 2, color = color7)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
                ax.set_ylabel('Pressure (hPa)', fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds7_name, fontsize = 15)
                                    
            if (plot_num >= 8):                
                plt.subplot(gs[2, 1])
                plt.plot(LWAV(var8),ds8.lev.values, lw = 2, color = color8)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds8_name, fontsize = 15)
                    
            if (plot_num >= 9):                
                plt.subplot(gs[2, 2])
                plt.plot(LWAV(var9),ds9.lev.values, lw = 2, color = color9)
                ax = plt.gca()
                ax.set_ylim([1000,10**logtop])
                ax.set_yscale('log')
                ax.set_xscale('log')
                if (xscale == 'Linear'): ax.set_xscale('linear')
                if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
                ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
                plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
                plt.title(ds9_name, fontsize = 15)

        #plot global mean vertical profile of chemical mixing ratio/temperature on same plots
        elif (same_plot == True):
            plt.subplot(gs[0, 0])
            plt.plot(LWAV(var1),ds1.lev.values, color = color1, lw = 2, label = ds1_name)
            if (plot_num >= 2):
                plt.plot(LWAV(var2),ds2.lev.values, color = color2, lw = 2, label = ds2_name)
            if (plot_num >= 3):
                plt.plot(LWAV(var3),ds3.lev.values, color = color3, lw = 2, label = ds3_name)
            if (plot_num >= 4):
                plt.plot(LWAV(var4),ds4.lev.values, color = color4, lw = 2, label = ds4_name)
            if (plot_num >= 5):
                plt.plot(LWAV(var5),ds5.lev.values, color = color5, lw = 2, label = ds5_name)
            if (plot_num >= 6):
                plt.plot(LWAV(var6),ds6.lev.values, color = color6, lw = 2, label = ds6_name)
            if (plot_num >= 7):
                plt.plot(LWAV(var7),ds7.lev.values, color = color7, lw = 2, label = ds7_name)
            if (plot_num >= 8):
                plt.plot(LWAV(var8),ds8.lev.values, color = color8, lw = 2, label = ds8_name)
            if (plot_num >= 9):
                plt.plot(LWAV(var9),ds9.lev.values, color = color9, lw = 2, label = ds9_name)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            if (xscale == 'Linear'): ax.set_xscale('linear')
            if (xscale == 'Symmetric log'): ax.set_xscale('symlog')
            ax.set_ylabel('Pressure (hPa)', fontsize = 15)
            ax.set_xlabel(xlabels(plot_num = fields), fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, width = 2)
            plt.legend(loc = 0, frameon = False, fontsize = 15)
            
        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return

# %%
#Lattude-longitude plots: function definitions    
def Lat_Lon_Plot(plot_num = 1, logtop=-4, field = 'T', level = 0, cmap = 'Blues',
                   fig_width = 7, fig_height = 4, save = False):
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
    gs = gridspec.GridSpec(1, 1) #1 column
            
    #asign variable from datasets 
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        #sort out subplots
        if (plot_num == 2):
            gs = gridspec.GridSpec(1, 2) #2 columns
        if (plot_num == 3):
            gs = gridspec.GridSpec(1, 3) #3 columns
        if (plot_num >= 4 and plot_num <= 6):
            gs = gridspec.GridSpec(2, 3) #2 rows 3 columns
            gs.update(hspace = 0.3)
        if (plot_num >= 7 and plot_num <= 9):
            gs = gridspec.GridSpec(3, 3) #3 rows 3 columns
            gs.update(hspace = 0.3)

        plt.subplot(gs[0, 0])
        model = var1[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
        plt.title(ds1_name, fontsize = 15)
        plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
        plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
        plt.ylabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
        if (plot_num >= 2):
            plt.subplot(gs[0, 1])
            var2[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
            plt.title(ds2_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
        if (plot_num >= 3):
            plt.subplot(gs[0, 2])
            var3[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
            plt.title(ds3_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
        if (plot_num >= 4):
            plt.subplot(gs[1, 0])
            var4[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
            plt.title(ds4_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.ylabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
        if (plot_num >= 5):
            plt.subplot(gs[1, 1])
            var5[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
            plt.title(ds5_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
        if (plot_num >= 6):
            plt.subplot(gs[1, 2])
            var6[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
            plt.title(ds6_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
        if (plot_num >= 7):
            plt.subplot(gs[2, 0])
            var7[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
            plt.title(ds7_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.ylabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
        if (plot_num >= 8):
            plt.subplot(gs[2, 1])
            var8[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
            plt.title(ds8_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
        if (plot_num >= 9):
            plt.subplot(gs[2, 2])
            var9[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
            plt.title(ds9_name, fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, labelleft = False, right = True, width = 2)
            plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
        #add colourbar
        cax = Figure.add_axes([0.94,0.125,0.02,0.755])
        cbar = plt.colorbar(model, cax=cax)
        if (field != 'T'): cbar.set_label(field+' mixing ratio',size=15)
        if (field == 'T'): cbar.set_label('Temperature [K]',size=15)
        cbar.ax.tick_params(labelsize=15)  

        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return   

def Lat_Lon_Difference_Plot(Dataset1 = 1, Dataset2 = 2, logtop=-4, field = 'T', level = 0, cmap = 'Blues',
                   fig_width = 7, fig_height = 4, percentage = False, save = False):
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
            
    #asign variable from datasets 
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        Difference = var1 - var2; Title = ds1_name+' - '+ds2_name
        if (percentage == False):
            # 1st DS
            if (Dataset1 == 'DS1' and Dataset2 == 'DS2'): Difference = var1 - var2; Title = ds1_name+' - '+ds2_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS3'): Difference = var1 - var3; Title = ds1_name+' - '+ds3_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS4'): Difference = var1 - var4; Title = ds1_name+' - '+ds4_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS5'): Difference = var1 - var5; Title = ds1_name+' - '+ds5_name
            # 2nd DS
            if (Dataset1 == 'DS2' and Dataset2 == 'DS3'): Difference = var2 - var3; Title = ds2_name+' - '+ds3_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS1'): Difference = var2 - var1; Title = ds2_name+' - '+ds1_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS4'): Difference = var2 - var4; Title = ds2_name+' - '+ds4_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS5'): Difference = var2 - var5; Title = ds2_name+' - '+ds5_name 
            # 3rd DS
            if (Dataset1 == 'DS3' and Dataset2 == 'DS2'): Difference = var3 - var2; Title = ds3_name+' - '+ds2_name  
            if (Dataset1 == 'DS3' and Dataset2 == 'DS1'): Difference = var3 - var1; Title = ds3_name+' - '+ds1_name
            if (Dataset1 == 'DS3' and Dataset2 == 'DS4'): Difference = var3 - var4; Title = ds3_name+' - '+ds4_name  
            if (Dataset1 == 'DS3' and Dataset2 == 'DS5'): Difference = var3 - var5; Title = ds3_name+' - '+ds5_name
            # 4th DS
            if (Dataset1 == 'DS4' and Dataset2 == 'DS2'): Difference = var4 - var2; Title = ds4_name+' - '+ds2_name  
            if (Dataset1 == 'DS4' and Dataset2 == 'DS1'): Difference = var4 - var1; Title = ds4_name+' - '+ds1_name
            if (Dataset1 == 'DS4' and Dataset2 == 'DS3'): Difference = var4 - var3; Title = ds4_name+' - '+ds3_name  
            if (Dataset1 == 'DS4' and Dataset2 == 'DS5'): Difference = var4 - var5; Title = ds4_name+' - '+ds5_name
            # 5th DS
            if (Dataset1 == 'DS5' and Dataset2 == 'DS2'): Difference = var5 - var2; Title = ds5_name+' - '+ds2_name  
            if (Dataset1 == 'DS5' and Dataset2 == 'DS1'): Difference = var5 - var1; Title = ds5_name+' - '+ds1_name
            if (Dataset1 == 'DS5' and Dataset2 == 'DS4'): Difference = var5 - var4; Title = ds5_name+' - '+ds4_name  
            if (Dataset1 == 'DS5' and Dataset2 == 'DS3'): Difference = var5 - var5; Title = ds5_name+' - '+ds3_name
        if (percentage == True):
            # 1st DS
            if (Dataset1 == 'DS1' and Dataset2 == 'DS2'): Difference = 100*(var1 - var2)/var1; Title = ds1_name+' - '+ds2_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS3'): Difference = 100*(var1 - var3)/var1; Title = ds1_name+' - '+ds3_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS4'): Difference = 100*(var1 - var4)/var1; Title = ds1_name+' - '+ds4_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS5'): Difference = 100*(var1 - var5)/var1; Title = ds1_name+' - '+ds5_name+' %'
            # 2nd DS
            if (Dataset1 == 'DS2' and Dataset2 == 'DS3'): Difference = 100*(var2 - var3)/var2; Title = ds2_name+' - '+ds3_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS1'): Difference = 100*(var2 - var1)/var2; Title = ds2_name+' - '+ds1_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS4'): Difference = 100*(var2 - var4)/var2; Title = ds2_name+' - '+ds4_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS5'): Difference = 100*(var2 - var5)/var2; Title = ds2_name+' - '+ds5_name +' %'
            # 3rd DS
            if (Dataset1 == 'DS3' and Dataset2 == 'DS2'): Difference = 100*(var3 - var2)/var3; Title = ds3_name+' - '+ds2_name +' %' 
            if (Dataset1 == 'DS3' and Dataset2 == 'DS1'): Difference = 100*(var3 - var1)/var3; Title = ds3_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS3' and Dataset2 == 'DS4'): Difference = 100*(var3 - var4)/var3; Title = ds3_name+' - '+ds4_name +' %' 
            if (Dataset1 == 'DS3' and Dataset2 == 'DS5'): Difference = 100*(var3 - var5)/var3; Title = ds3_name+' - '+ds5_name+' %'
            # 4th DS
            if (Dataset1 == 'DS4' and Dataset2 == 'DS2'): Difference = 100*(var4 - var2)/var4; Title = ds4_name+' - '+ds2_name  +' %'
            if (Dataset1 == 'DS4' and Dataset2 == 'DS1'): Difference = 100*(var4 - var1)/var4; Title = ds4_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS4' and Dataset2 == 'DS3'): Difference = 100*(var4 - var3)/var4; Title = ds4_name+' - '+ds3_name +' %' 
            if (Dataset1 == 'DS4' and Dataset2 == 'DS5'): Difference = 100*(var4 - var5)/var4; Title = ds4_name+' - '+ds5_name+' %'
            # 5th DS
            if (Dataset1 == 'DS5' and Dataset2 == 'DS2'): Difference = 100*(var5 - var2)/var5; Title = ds5_name+' - '+ds2_name  +' %'
            if (Dataset1 == 'DS5' and Dataset2 == 'DS1'): Difference = 100*(var5 - var1)/var5; Title = ds5_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS5' and Dataset2 == 'DS4'): Difference = 100*(var5 - var4)/var5; Title = ds5_name+' - '+ds4_name +' %' 
            if (Dataset1 == 'DS5' and Dataset2 == 'DS3'): Difference = 100*(var5 - var5)/var5; Title = ds5_name+' - '+ds3_name+' %'
        
        model = Difference[level,:,:].plot.pcolormesh(cmap = cmap, add_labels=False, add_colorbar = False)
        plt.title(Title, fontsize = 15)
        plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
        plt.xlabel('Longitude ['+r'$^\circ$'+']', fontsize = 15)
        plt.ylabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
        #add colourbar
        cax = Figure.add_axes([0.94,0.125,0.02,0.755])
        cbar = plt.colorbar(model, cax=cax)
        if (field != 'T' and percentage == False): cbar.set_label(field+' mixing ratio difference',size=15)
        if (field != 'T' and percentage == True): cbar.set_label(field+' mixing ratio difference [%]',size=15)
        if (field == 'T' and percentage == False): cbar.set_label('Temperature difference [K]',size=15)
        if (field == 'T' and percentage == True): cbar.set_label('Temperature difference [%]',size=15)
        cbar.ax.tick_params(labelsize=15)  

        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return

# %%
#Fixed longitude plots: function definitions    
def Fixed_Lon_Plot(plot_num = 1, logtop=-4, field = 'T', lon_index = 0, cmap = 'Blues',
                   fig_width = 7, fig_height = 4, save = False):
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
    gs = gridspec.GridSpec(1, 1) #1 column
            
    #asign variable from datasets 
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        #sort out subplots
        if (plot_num == 2):
            gs = gridspec.GridSpec(1, 2) #2 columns
        if (plot_num == 3):
            gs = gridspec.GridSpec(1, 3) #3 columns
        if (plot_num >= 4 and plot_num <= 6):
            gs = gridspec.GridSpec(2, 3) #2 rows 3 columns
            gs.update(hspace = 0.3)
        if (plot_num >= 7 and plot_num <= 9):
            gs = gridspec.GridSpec(3, 3) #3 rows 3 columns
            gs.update(hspace = 0.3)

        plt.subplot(gs[0, 0])
        a = var1[:,:,lon_index]
        model = a.where(ds1.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
        ax = plt.gca()
        ax.set_ylim([1000,10**logtop])
        ax.set_yscale('log')
        ax.set_ylabel('Pressure (hPa)', fontsize = 15)
        plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
        plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
        plt.title(ds1_name, fontsize = 15)

        if (plot_num >= 2):
            plt.subplot(gs[0, 1])
            a = var2[:,:,lon_index]
            a.where(ds2.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.tick_params(labelsize = 15, labelleft = False, length = 4, width = 2)
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds2_name, fontsize = 15)

        if (plot_num >= 3):
            plt.subplot(gs[0, 2])
            a = var3[:,:,lon_index]
            a.where(ds3.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.tick_params(labelsize = 15, labelleft = False, length = 4, width = 2)
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds3_name, fontsize = 15)
        
        if (plot_num >= 4):
            plt.subplot(gs[1, 0])
            a = var4[:,:,lon_index]
            a.where(ds4.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_ylabel('Pressure (hPa)', fontsize = 15)
            plt.tick_params(labelsize = 15, length = 4, width = 2)
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds4_name, fontsize = 15)
            
        if (plot_num >= 5):
            plt.subplot(gs[1, 1])
            a = var5[:,:,lon_index]
            a.where(ds5.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.tick_params(labelsize = 15, labelleft = False, length = 4, width = 2)
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds5_name, fontsize = 15)
        
        if (plot_num >= 6):
            plt.subplot(gs[1, 2])
            a = var6[:,:,lon_index]
            a.where(ds6.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.tick_params(labelsize = 15, labelleft = False, length = 4, width = 2)
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds6_name, fontsize = 15)
        
        if (plot_num >= 7):
            plt.subplot(gs[2, 0])
            a = var7[:,:,lon_index]
            a.where(ds7.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.tick_params(labelsize = 15, length = 4, width = 2)
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.ylabel('Pressure [hPa]', fontsize = 15)
            plt.title(ds7_name, fontsize = 15)
            
        if (plot_num >= 8):
            plt.subplot(gs[2, 1])
            a = var8[:,:,lon_index]
            a.where(ds8.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.tick_params(labelsize = 15, labelleft = False, length = 4, width = 2)
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds8_name, fontsize = 15)
            
        if (plot_num >= 9):
            plt.subplot(gs[2, 2])
            a = var9[:,:,lon_index]
            a.where(ds9.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            plt.tick_params(labelsize = 15, labelleft = False, length = 4, width = 2)
            plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
            plt.title(ds9_name, fontsize = 15)
        #add colourbar
        cax = Figure.add_axes([0.94,0.125,0.02,0.755])
        cbar = plt.colorbar(model, cax=cax)
        if (field != 'T'): cbar.set_label(field+' mixing ratio', size=15)
        if (field == 'T'): cbar.set_label('Temperature [K]', size=15)
        cbar.ax.tick_params(labelsize=15) 

        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return   

def Fixed_Lon_Difference_Plot(Dataset1 = 'DS1', Dataset2 = 'DS2', logtop=-4, field = 'T', lon_index = 0, cmap = 'Blues',
                   fig_width = 7, fig_height = 4, percentage = False, save = False):
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
            
    #asign variable from datasets 
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #asign variable from datasets    
        
        var1 = var1.mean(dim = 'time')
        var2 = var2.mean(dim = 'time')
        var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time')
        var5 = var5.mean(dim = 'time')
        var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time')
        var8 = var8.mean(dim = 'time')
        var9 = var9.mean(dim = 'time')
        
        Difference = var1 - var2; Title = ds1_name+' - '+ds2_name
        if (percentage == False):
            # 1st DS
            if (Dataset1 == 'DS1' and Dataset2 == 'DS2'): Difference = var1 - var2; Title = ds1_name+' - '+ds2_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS3'): Difference = var1 - var3; Title = ds1_name+' - '+ds3_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS4'): Difference = var1 - var4; Title = ds1_name+' - '+ds4_name
            if (Dataset1 == 'DS1' and Dataset2 == 'DS5'): Difference = var1 - var5; Title = ds1_name+' - '+ds5_name
            # 2nd DS
            if (Dataset1 == 'DS2' and Dataset2 == 'DS3'): Difference = var2 - var3; Title = ds2_name+' - '+ds3_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS1'): Difference = var2 - var1; Title = ds2_name+' - '+ds1_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS4'): Difference = var2 - var4; Title = ds2_name+' - '+ds4_name 
            if (Dataset1 == 'DS2' and Dataset2 == 'DS5'): Difference = var2 - var5; Title = ds2_name+' - '+ds5_name 
            # 3rd DS
            if (Dataset1 == 'DS3' and Dataset2 == 'DS2'): Difference = var3 - var2; Title = ds3_name+' - '+ds2_name  
            if (Dataset1 == 'DS3' and Dataset2 == 'DS1'): Difference = var3 - var1; Title = ds3_name+' - '+ds1_name
            if (Dataset1 == 'DS3' and Dataset2 == 'DS4'): Difference = var3 - var4; Title = ds3_name+' - '+ds4_name  
            if (Dataset1 == 'DS3' and Dataset2 == 'DS5'): Difference = var3 - var5; Title = ds3_name+' - '+ds5_name
            # 4th DS
            if (Dataset1 == 'DS4' and Dataset2 == 'DS2'): Difference = var4 - var2; Title = ds4_name+' - '+ds2_name  
            if (Dataset1 == 'DS4' and Dataset2 == 'DS1'): Difference = var4 - var1; Title = ds4_name+' - '+ds1_name
            if (Dataset1 == 'DS4' and Dataset2 == 'DS3'): Difference = var4 - var3; Title = ds4_name+' - '+ds3_name  
            if (Dataset1 == 'DS4' and Dataset2 == 'DS5'): Difference = var4 - var5; Title = ds4_name+' - '+ds5_name
            # 5th DS
            if (Dataset1 == 'DS5' and Dataset2 == 'DS2'): Difference = var5 - var2; Title = ds5_name+' - '+ds2_name  
            if (Dataset1 == 'DS5' and Dataset2 == 'DS1'): Difference = var5 - var1; Title = ds5_name+' - '+ds1_name
            if (Dataset1 == 'DS5' and Dataset2 == 'DS4'): Difference = var5 - var4; Title = ds5_name+' - '+ds4_name  
            if (Dataset1 == 'DS5' and Dataset2 == 'DS3'): Difference = var5 - var5; Title = ds5_name+' - '+ds3_name
        if (percentage == True):
            # 1st DS
            if (Dataset1 == 'DS1' and Dataset2 == 'DS2'): Difference = 100*(var1 - var2)/var1; Title = ds1_name+' - '+ds2_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS3'): Difference = 100*(var1 - var3)/var1; Title = ds1_name+' - '+ds3_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS4'): Difference = 100*(var1 - var4)/var1; Title = ds1_name+' - '+ds4_name+' %'
            if (Dataset1 == 'DS1' and Dataset2 == 'DS5'): Difference = 100*(var1 - var5)/var1; Title = ds1_name+' - '+ds5_name+' %'
            # 2nd DS
            if (Dataset1 == 'DS2' and Dataset2 == 'DS3'): Difference = 100*(var2 - var3)/var2; Title = ds2_name+' - '+ds3_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS1'): Difference = 100*(var2 - var1)/var2; Title = ds2_name+' - '+ds1_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS4'): Difference = 100*(var2 - var4)/var2; Title = ds2_name+' - '+ds4_name +' %'
            if (Dataset1 == 'DS2' and Dataset2 == 'DS5'): Difference = 100*(var2 - var5)/var2; Title = ds2_name+' - '+ds5_name +' %'
            # 3rd DS
            if (Dataset1 == 'DS3' and Dataset2 == 'DS2'): Difference = 100*(var3 - var2)/var3; Title = ds3_name+' - '+ds2_name +' %' 
            if (Dataset1 == 'DS3' and Dataset2 == 'DS1'): Difference = 100*(var3 - var1)/var3; Title = ds3_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS3' and Dataset2 == 'DS4'): Difference = 100*(var3 - var4)/var3; Title = ds3_name+' - '+ds4_name +' %' 
            if (Dataset1 == 'DS3' and Dataset2 == 'DS5'): Difference = 100*(var3 - var5)/var3; Title = ds3_name+' - '+ds5_name+' %'
            # 4th DS
            if (Dataset1 == 'DS4' and Dataset2 == 'DS2'): Difference = 100*(var4 - var2)/var4; Title = ds4_name+' - '+ds2_name  +' %'
            if (Dataset1 == 'DS4' and Dataset2 == 'DS1'): Difference = 100*(var4 - var1)/var4; Title = ds4_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS4' and Dataset2 == 'DS3'): Difference = 100*(var4 - var3)/var4; Title = ds4_name+' - '+ds3_name +' %' 
            if (Dataset1 == 'DS4' and Dataset2 == 'DS5'): Difference = 100*(var4 - var5)/var4; Title = ds4_name+' - '+ds5_name+' %'
            # 5th DS
            if (Dataset1 == 'DS5' and Dataset2 == 'DS2'): Difference = 100*(var5 - var2)/var5; Title = ds5_name+' - '+ds2_name  +' %'
            if (Dataset1 == 'DS5' and Dataset2 == 'DS1'): Difference = 100*(var5 - var1)/var5; Title = ds5_name+' - '+ds1_name+' %'
            if (Dataset1 == 'DS5' and Dataset2 == 'DS4'): Difference = 100*(var5 - var4)/var5; Title = ds5_name+' - '+ds4_name +' %' 
            if (Dataset1 == 'DS5' and Dataset2 == 'DS3'): Difference = 100*(var5 - var5)/var5; Title = ds5_name+' - '+ds3_name+' %'
        
        a = Difference[:,:,lon_index]
        model = a.where(ds1.coords["lev"] > 10**logtop).plot.pcolormesh(cmap = cmap,add_labels=False, add_colorbar = False)
        ax = plt.gca()
        ax.set_ylim([1000,10**logtop])
        ax.set_yscale('log')
        ax.set_ylabel('Pressure (hPa)', fontsize = 15)
        plt.tick_params(labelsize = 15, length = 4, right = True, width = 2)
        plt.xlabel('Latitude ['+r'$^\circ$'+']', fontsize = 15)
        plt.title(Title, fontsize = 15)

        #add colourbar
        cax = Figure.add_axes([0.94,0.125,0.02,0.755])
        cbar = plt.colorbar(model, cax=cax)
        if (field != 'T'): cbar.set_label(field+' mixing ratio', size=15)
        if (field == 'T'): cbar.set_label('Temperature [K]', size=15)
        cbar.ax.tick_params(labelsize=15) 

        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return

# %%
import cartopy.crs as ccrs
import cartopy

def Earth_Plot(plot_num = 1, field = 'T', cmap = 'coolwarm', lon = 0, lat = 0,
                   fig_width = 7, fig_height = 4, level = 69, save = False):
    
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
    
    #sort out subplots
    rows = 1; cols = 1
    if (plot_num == 2):
        rows = 1; cols = 2
    if (plot_num == 3):
        rows = 1; cols = 3
    if (plot_num >= 4 and plot_num <= 6):
        rows = 2; cols = 3
    if (plot_num >= 7 and plot_num <= 9):
        rows = 3; cols = 3
            
    #asign variable from datasets    
    var1 = ds1[field]
    var2 = ds2[field]
    var3 = ds3[field]
    var4 = ds4[field]
    var5 = ds5[field]
    var6 = ds6[field]
    var7 = ds7[field]
    var8 = ds8[field]
    var9 = ds9[field]
    
    var1 = var1.mean(dim = 'time')
    var2 = var2.mean(dim = 'time')
    var3 = var3.mean(dim = 'time')
    var4 = var4.mean(dim = 'time')
    var5 = var5.mean(dim = 'time')
    var6 = var6.mean(dim = 'time')
    var7 = var7.mean(dim = 'time')
    var8 = var8.mean(dim = 'time')
    var9 = var9.mean(dim = 'time') 
    
    if (var1.dims == ('lev','lat', 'lon')):
        var1 = var1.isel(lev = level)
        var2 = var2.isel(lev = level)
        var3 = var3.isel(lev = level)
        var4 = var4.isel(lev = level)
        var5 = var5.isel(lev = level)
        var6 = var6.isel(lev = level)
        var7 = var7.isel(lev = level)
        var8 = var8.isel(lev = level)
        var9 = var9.isel(lev = level)
    
    if (var1.dims == ('lat', 'lon')):
        Fontsize = 15
        #max and min values in order to set a consisten 
        
        Values = Store_values(var1 = var1, var2 = var2, var3 = var3, var4 = var4, var5 = var5,
                    var6 = var6, var7 = var7, var8 = var8, var9 = var9, plot_num = plot_num)
        
        #colour map and log bool
        cmap = cmap
        #1st plot
        logc = False

        ax1 = plt.subplot2grid((rows,cols), (0,0), projection=ccrs.Orthographic(central_longitude=lon, central_latitude=lat))
        ax1.coastlines(resolution='110m')
        model = var1.plot(cmap = cmap, add_labels=False, add_colorbar = False, vmin=Values.min(),vmax=Values.max(), transform=ccrs.PlateCarree())
        plt.title(ds1_name, fontsize = 15)
        
        if (plot_num >= 2):
            ax2 = plt.subplot2grid((rows,cols), (0,1), projection=ccrs.Orthographic(central_longitude=lon, central_latitude=lat))
            ax2.coastlines(resolution='110m')
            model = var2.plot(cmap = cmap, add_labels=False, add_colorbar = False, vmin=Values.min(),vmax=Values.max(), transform=ccrs.PlateCarree())
            plt.title(ds2_name, fontsize = 15)
        
        if (plot_num >= 3):
            ax3 = plt.subplot2grid((rows,cols), (0,2), projection=ccrs.Orthographic(central_longitude=lon, central_latitude=lat))
            ax3.coastlines(resolution='110m')
            model = var3.plot(cmap = cmap, add_labels=False, add_colorbar = False, vmin=Values.min(),vmax=Values.max(), transform=ccrs.PlateCarree())
            plt.title(ds3_name, fontsize = 15)
        
        if (plot_num >= 4):
            ax4 = plt.subplot2grid((rows,cols), (1,0), projection=ccrs.Orthographic(central_longitude=lon, central_latitude=lat))
            ax4.coastlines(resolution='110m')
            model = var4.plot(cmap = cmap, add_labels=False, add_colorbar = False, vmin=Values.min(),vmax=Values.max(), transform=ccrs.PlateCarree())
            plt.title(ds4_name, fontsize = 15)
        
        if (plot_num >= 5):
            ax5 = plt.subplot2grid((rows,cols), (1,1), projection=ccrs.Orthographic(central_longitude=lon, central_latitude=lat))
            ax5.coastlines(resolution='110m')
            model = var5.plot(cmap = cmap, add_labels=False, add_colorbar = False, vmin=Values.min(),vmax=Values.max(), transform=ccrs.PlateCarree())
            plt.title(ds5_name, fontsize = 15)
            
        if (plot_num >= 5):
            ax6 = plt.subplot2grid((rows,cols), (1,2), projection=ccrs.Orthographic(central_longitude=lon, central_latitude=lat))
            ax6.coastlines(resolution='110m')
            model = var6.plot(cmap = cmap, add_labels=False, add_colorbar = False, vmin=Values.min(),vmax=Values.max(), transform=ccrs.PlateCarree())
            plt.title(ds6_name, fontsize = 15)
        
        if (plot_num >= 7):
            ax7 = plt.subplot2grid((rows,cols), (2,0), projection=ccrs.Orthographic(central_longitude=lon, central_latitude=lat))
            ax7.coastlines(resolution='110m')
            model = var7.plot(cmap = cmap, add_labels=False, add_colorbar = False, vmin=Values.min(),vmax=Values.max(), transform=ccrs.PlateCarree())
            plt.title(ds7_name, fontsize = 15)
        
        if (plot_num >= 8):
            ax8 = plt.subplot2grid((rows,cols), (2,1), projection=ccrs.Orthographic(central_longitude=lon, central_latitude=lat))
            ax8.coastlines(resolution='110m')
            model = var8.plot(cmap = cmap, add_labels=False, add_colorbar = False, vmin=Values.min(),vmax=Values.max(), transform=ccrs.PlateCarree())
            plt.title(ds8_name, fontsize = 15)
            
        if (plot_num >= 9):
            ax9 = plt.subplot2grid((rows,cols), (2,2), projection=ccrs.Orthographic(central_longitude=lon, central_latitude=lat))
            ax9.coastlines(resolution='110m')
            model = var9.plot(cmap = cmap, add_labels=False, add_colorbar = False, vmin=Values.min(),vmax=Values.max(), transform=ccrs.PlateCarree())
            plt.title(ds9_name, fontsize = 15)

        #add colour bar
        cax = Figure.add_axes([0.94, 0.125,0.02,0.75])
        if (logc == True):
            cbar = plt.colorbar(model, cax=cax)
        else:
            cbar = plt.colorbar(model, cax=cax)#, format=ticker.FuncFormatter(fmt))

        clabel = field_labels(field = field)
        if (field == 'T'): clabel = 'Temperature [K]'
        if (field == 'U'): clabel = 'Zonal wind ms'+r'$^{-1}$'
        if (field == 'V'): clabel = 'Meridional wind ms'+r'$^{-1}$'
        if (field == 'ICEFRAC'): clabel = 'Sea ice fraction'
        cbar.set_label(clabel,size=Fontsize)
        cbar.ax.tick_params(labelsize=Fontsize)

        if (save == True):
                    plt.savefig('test.png', bbox_inches='tight')
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()

# %%
#%% Plot a single Earth projection - vectors

def zonal_mean_surface(DS,Var,level):
    if (len(ds1[Var].dims) > 3):
        DS = DS[Var].mean(dim = 'time')
        DS = DS.isel(lev = level)
    else:
        DS = DS[Var].mean(dim = 'time')
    return DS

def retrieve_data(var1, var2, ds, shape=(144, 96)):
    """
    Returns ``(x, y, u, v, crs)`` of some vector data
    computed mathematically. The returned crs will be a rotated
    pole CRS, meaning that the vectors will be unevenly spaced in
    regular PlateCarree space.

    """
    crs = ccrs.RotatedPole(pole_longitude=0, pole_latitude=90)
    
    ds = ds
    
    lon = ds.lon.values[np.arange(0,144,4)]
    lat = ds.lat.values[np.arange(0,96,2)]
    
    U = zonal_mean_surface(ds,var1,69).values[np.arange(0,96,2),:]
    U = U[:,np.arange(0,144,4)]
    V = zonal_mean_surface(ds,var2,69).values[np.arange(0,96,2),:]
    V = V[:,np.arange(0,144,4)]

    return lon, lat, U, V, crs

def Plot_Earth_Vectors(lon = 0, lat = 0, plot_num = 1, fig_width = 5, fig_height = 5, 
                       Borders = False, Land = False, Ocean = False, Grid = False, 
                       Rivers_Lakes = False):

    def Add_Earth_Features():
        zorder1 = 0; zorder2 = 0; Design = ''
        if (Ocean == True):
            zorder1 = 1; Design = '_Ocean'
        if (Land == True):
            zorder2 = 1; Design = '_Land'
        ax.add_feature(cartopy.feature.OCEAN, zorder=zorder1, facecolor = 'royalblue')
        ax.add_feature(cartopy.feature.LAND, zorder=zorder2, edgecolor='black', facecolor = 'forestgreen')

        if (Rivers_Lakes == True):
            import cartopy.feature as cfeature
            rivers_50m = cfeature.NaturalEarthFeature('physical', 'rivers_lake_centerlines', '50m')
            ax.add_feature(rivers_50m, facecolor='None', edgecolor='skyblue')
            ax.add_feature(cartopy.feature.RIVERS, zorder=zorder2, edgecolor = 'skyblue')#, facecolor = 'royalblue')
            ax.add_feature(cartopy.feature.LAKES, zorder=zorder2, edgecolor = 'skyblue', facecolor = 'skyblue')
        Border = ''
        if (Borders == True):
            Border = 'Borders'    
            ax.add_feature(cartopy.feature.BORDERS, zorder=zorder2, edgecolor = 'k')

        ax.set_global()
        if (Grid == True):
            ax.gridlines()
            
    Figure = plt.figure(figsize=(fig_width, fig_height))
    #change the longitude and latiude below of where you would like to centre the image
    var1 = 'U'; var2 = 'V'
    lon_centre = lon; lat_centre = lat
    ax = plt.subplot2grid((1,plot_num), (0,0), projection=ccrs.Orthographic(central_longitude=lon_centre, central_latitude=lat_centre))
    Add_Earth_Features()
    x, y, u, v, vector_crs = retrieve_data(var1 = var1, var2 = var2, ds = ds1)
    ax.quiver(x, y, u, v, transform=vector_crs, color = 'k', minshaft = 2, width =0.004, headwidth = 9)
    plt.title(ds1_name+ '\nmean winds', fontsize = 20)
    
    if (plot_num >= 2):
        ax = plt.subplot2grid((1,plot_num), (0,1), projection=ccrs.Orthographic(central_longitude=lon_centre, central_latitude=lat_centre))
        Add_Earth_Features()
        x, y, u, v, vector_crs = retrieve_data(var1 = var1, var2 = var2, ds = ds2)
        ax.quiver(x, y, u, v, transform=vector_crs, color = 'k', minshaft = 2, width =0.004, headwidth = 9)
        plt.title(ds2_name+ '\nmean winds', fontsize = 20)

    if (plot_num >= 3):
        ax = plt.subplot2grid((1,plot_num), (0,2), projection=ccrs.Orthographic(central_longitude=lon_centre, central_latitude=lat_centre))
        Add_Earth_Features()
        x, y, u, v, vector_crs = retrieve_data(var1 = var1, var2 = var2, ds = ds3)
        ax.quiver(x, y, u, v, transform=vector_crs, color = 'k', minshaft = 2, width =0.004, headwidth = 9)
        plt.title(ds3_name+ '\nmean winds', fontsize = 20)

    if (plot_num >= 4):
        ax = plt.subplot2grid((1,plot_num), (0,3), projection=ccrs.Orthographic(central_longitude=lon_centre, central_latitude=lat_centre))
        Add_Earth_Features()
        x, y, u, v, vector_crs = retrieve_data(var1 = var1, var2 = var2, ds = ds4)
        ax.quiver(x, y, u, v, transform=vector_crs, color = 'k', minshaft = 2, width =0.004, headwidth = 9)
        plt.title(ds4_name+ '\nmean winds', fontsize = 20)

    if (plot_num >= 5):
        ax = plt.subplot2grid((1,plot_num), (0,4), projection=ccrs.Orthographic(central_longitude=lon_centre, central_latitude=lat_centre))
        Add_Earth_Features()
        x, y, u, v, vector_crs = retrieve_data(var1 = var1, var2 = var2, ds = ds5)
        ax.quiver(x, y, u, v, transform=vector_crs, color = 'k', minshaft = 2, width =0.004, headwidth = 9)
        plt.title(ds5_name+ '\nmean winds', fontsize = 20)

# %%
def Plot_Many_Vertical(plot_num = 1, ds_num = 1, logtop=-4.5, field1 = 'T', field2 = 'H2O', field3 = 'CH4',
                       field4 = 'H2', field5 = 'H', field6 = 'CO2', field7 = 'O2', field8 = 'O', field9 = 'O3',
                       field10 = 'NOX', field11 = 'HOX', field12 = 'N', legend_pos = 1,
                          fig_width = 7, fig_height = 4, save = False):
    
    #get figure size
    Figure = plt.figure(figsize=(fig_width, fig_height))
    gs = gridspec.GridSpec(1, 1) #1 column
            
    #asign variable from datasets 
    var1 = ds1[field1]; var2 = ds2[field1]; var3 = ds3[field1]; var4 = ds4[field1]; var5 = ds5[field1]
    var6 = ds6[field1]; var7 = ds7[field1]; var8 = ds8[field1]; var9 = ds9[field1]
    
    if (var1.dims == ('time','lev', 'lat', 'lon')):
        #take time mean  
        var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
        var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
        var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        #sort out subplots
        if (plot_num == 2):
            gs = gridspec.GridSpec(1, 2) #2 columns
        if (plot_num == 3):
            gs = gridspec.GridSpec(1, 3) #3 columns
        if (plot_num == 4):
            gs = gridspec.GridSpec(1, 4) #3 columns
        if (plot_num >= 5 and plot_num <= 8):
            gs = gridspec.GridSpec(2, 4) #2 rows 4 columns
            gs.update(hspace = 0.3)
        if (plot_num >= 9 and plot_num <= 12):
            gs = gridspec.GridSpec(3, 4) #3 rows 4 columns
            gs.update(hspace = 0.3)

        plt.subplot(gs[0, 0])
        plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
        if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
        if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
        if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
        if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
        if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
        if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
        if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
        if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
        if (legend_pos == 1): plt.legend(loc = 0, frameon = False, fontsize = 12)
        ax = plt.gca()
        ax.set_ylim([1000,10**logtop])
        ax.set_yscale('log')
        ax.set_xscale('log')
        ax.set_ylabel('Pressure (hPa)', fontsize = 15)
        ax.set_xlabel(field_labels(field = field1), fontsize = 15)
        plt.tick_params(labelsize = 15, length = 4, width = 2)
        if (field1 =='T'):
            ax.set_xlabel('Temperature [K]', fontsize = 15)
            ax.set_xscale('linear')
        if (legend_pos == 1): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field2]; var2 = ds2[field2]; var3 = ds3[field2]; var4 = ds4[field2]; var5 = ds5[field2]
        var6 = ds6[field2]; var7 = ds7[field2]; var8 = ds8[field2]; var9 = ds9[field2]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 2):
            plt.subplot(gs[0, 1])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 2): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field2), fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
            if (field2 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 2): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field3]; var2 = ds2[field3]; var3 = ds3[field3]; var4 = ds4[field3]; var5 = ds5[field3]
        var6 = ds6[field3]; var7 = ds7[field3]; var8 = ds8[field3]; var9 = ds9[field3]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')
            
        if (plot_num >= 3):                
            plt.subplot(gs[0, 2]) 
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 3): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field3), fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
            if (field3 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 3): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field4]; var2 = ds2[field4]; var3 = ds3[field4]; var4 = ds4[field4]; var5 = ds5[field4]
        var6 = ds6[field4]; var7 = ds7[field4]; var8 = ds8[field4]; var9 = ds9[field4]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 4):                
            plt.subplot(gs[0, 3])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 4): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field4), fontsize = 15)
            plt.tick_params(labelsize = 15, right = True, labelleft = False, length = 4, width = 2)
            if (field4 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 4): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field5]; var2 = ds2[field5]; var3 = ds3[field5]; var4 = ds4[field5]; var5 = ds5[field5]
        var6 = ds6[field5]; var7 = ds7[field5]; var8 = ds8[field5]; var9 = ds9[field5]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 5):                
            plt.subplot(gs[1, 0])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 5): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field5), fontsize = 15)
            ax.set_ylabel('Pressure [hPa]', fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = True, right = True, length = 4, width = 2)
            if (field5 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 5): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field6]; var2 = ds2[field6]; var3 = ds3[field6]; var4 = ds4[field6]; var5 = ds5[field6]
        var6 = ds6[field6]; var7 = ds7[field6]; var8 = ds8[field6]; var9 = ds9[field6]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 6):                
            plt.subplot(gs[1, 1])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1)
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 6): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field6), fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
            if (field6 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 6): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field7]; var2 = ds2[field7]; var3 = ds3[field7]; var4 = ds4[field7]; var5 = ds5[field7]
        var6 = ds6[field7]; var7 = ds7[field7]; var8 = ds8[field7]; var9 = ds9[field7]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 7):                
            plt.subplot(gs[1, 2])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 7): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field7), fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
            if (field7 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 7): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field8]; var2 = ds2[field8]; var3 = ds3[field8]; var4 = ds4[field8]; var5 = ds5[field8]
        var6 = ds6[field8]; var7 = ds7[field8]; var8 = ds8[field8]; var9 = ds9[field8]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 8):                
            plt.subplot(gs[1, 3])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 8): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field8), fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
            if (field8 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 8): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field9]; var2 = ds2[field9]; var3 = ds3[field9]; var4 = ds4[field9]; var5 = ds5[field9]
        var6 = ds6[field9]; var7 = ds7[field9]; var8 = ds8[field9]; var9 = ds9[field9]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 9):                
            plt.subplot(gs[2, 0])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1)
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 9): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field9), fontsize = 15)
            ax.set_ylabel('Pressure [hPa]', fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = True, right = True, length = 4, width = 2)
            if (field9 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 9): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field10]; var2 = ds2[field10]; var3 = ds3[field10]; var4 = ds4[field10]; var5 = ds5[field10]
        var6 = ds6[field10]; var7 = ds7[field10]; var8 = ds8[field10]; var9 = ds9[field10]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 10):                
            plt.subplot(gs[2, 1])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 10): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field10), fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
            if (field10 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 10): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field11]; var2 = ds2[field11]; var3 = ds3[field11]; var4 = ds4[field11]; var5 = ds5[field11]
        var6 = ds6[field11]; var7 = ds7[field11]; var8 = ds8[field11]; var9 = ds9[field11]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 11):                
            plt.subplot(gs[2, 2])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 11): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field11), fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
            if (field11 =='T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 11): plt.legend(loc = 0, frameon = False, fontsize = 15)

        #asign variable from datasets 
        var1 = ds1[field12]; var2 = ds2[field12]; var3 = ds3[field12]; var4 = ds4[field12]; var5 = ds5[field12]
        var6 = ds6[field12]; var7 = ds7[field12]; var8 = ds8[field12]; var9 = ds9[field12]

        if (var1.dims == ('time','lev', 'lat', 'lon')):
            #take time mean  
            var1 = var1.mean(dim = 'time'); var2 = var2.mean(dim = 'time'); var3 = var3.mean(dim = 'time')
            var4 = var4.mean(dim = 'time'); var5 = var5.mean(dim = 'time'); var6 = var6.mean(dim = 'time')
            var7 = var7.mean(dim = 'time'); var8 = var8.mean(dim = 'time'); var9 = var9.mean(dim = 'time')

        if (plot_num >= 12):                
            plt.subplot(gs[2, 3])
            plt.plot(LWAV(var1),ds1.lev.values, lw = 2, color = color1, label = ds1_name)
            if (ds_num >= 2): plt.plot(LWAV(var2),ds1.lev.values, lw = 2, color = color2, label = ds2_name)
            if (ds_num >= 3): plt.plot(LWAV(var3),ds1.lev.values, lw = 2, color = color3, label = ds3_name)
            if (ds_num >= 4): plt.plot(LWAV(var4),ds1.lev.values, lw = 2, color = color4, label = ds4_name)
            if (ds_num >= 5): plt.plot(LWAV(var5),ds1.lev.values, lw = 2, color = color5, label = ds5_name)
            if (ds_num >= 6): plt.plot(LWAV(var6),ds1.lev.values, lw = 2, color = color6, label = ds6_name)
            if (ds_num >= 7): plt.plot(LWAV(var7),ds1.lev.values, lw = 2, color = color7, label = ds7_name)
            if (ds_num >= 8): plt.plot(LWAV(var8),ds1.lev.values, lw = 2, color = color8, label = ds8_name)
            if (ds_num >= 9): plt.plot(LWAV(var9),ds1.lev.values, lw = 2, color = color9, label = ds9_name)
            if (legend_pos == 12): plt.legend(loc = 0, frameon = False, fontsize = 12)
            ax = plt.gca()
            ax.set_ylim([1000,10**logtop])
            ax.set_yscale('log')
            ax.set_xscale('log')
            ax.set_xlabel(field_labels(field = field12), fontsize = 15)
            plt.tick_params(labelsize = 15, labelleft = False, right = True, length = 4, width = 2)
            if (field12 == 'T'):
                ax.set_xlabel('Temperature [K]', fontsize = 15)
                ax.set_xscale('linear')
            if (legend_pos == 12): plt.legend(loc = 0, frameon = False, fontsize = 15)

        if (save == True):
            plt.savefig('test.png', bbox_inches='tight')
    
    else:
        plt.scatter((0,360),(-90,90))
        plt.text(180, 0, 'select a 2-D or 3-D field', horizontalalignment='center')
        plt.show()
    return

# %%
def final_widget(plot_type):
    #Vertical profile plots
    if (plot_type ==  'Vertical profile plot'):
        VP = interactive(Vertical_Profile_Plot, field=ds1.data_vars.keys(), logtop=(-5,2,0.5), 
                         fig_height = (1,20,0.5), fig_width = (1,20,0.5), plot_num = (1,9,1),
                         xscale = ['log', 'Linear', 'Symmetric log'],save = [False, True])
        display(VP)
    if (plot_type ==  'Vertical profile difference plot'):
        VPD = interactive(Vertical_Profile_Difference_Plot, field=ds1.data_vars.keys(), logtop=(-5,2,0.5),
                          Dataset1 = ['DS1','DS2','DS3','DS4','DS5'],
                          Dataset2 = ['DS1','DS2','DS3','DS4','DS5'], 
                          fig_width = (1,20,0.5), plot_num = [1,2,3],
                          percentage = [False, True], save = [False, True])
        display(VPD)
    if (plot_type ==  'Add variables, vertical plot'):
        AVVP = interactive(Add_Vars_Vertical, same_plot = [True, False], plot_num = (1,9,1), logtop=(-5,2,0.5), 
                          fields=(2,5,1), field1 = ds1.data_vars.keys(),field2 = ds1.data_vars.keys(),
                          field3 = ds1.data_vars.keys(),field4 = ds1.data_vars.keys(),
                          field5 = ds1.data_vars.keys(),fig_height = (1,20,0.5), fig_width = (1,20,0.5),
                           xscale = ['log', 'Linear', 'Symmetric log'], save = [False, True]) 
        display(AVVP)    
    #Longitude-latitude plots    
    if (plot_type == 'Longitude-latitude plot'):
        LL = interactive(Lat_Lon_Plot, field=ds1.data_vars.keys(), logtop=(-5,2,0.5), level=(0,69,1),cmap=cmaps, 
                         fig_height = (1,20,0.5), fig_width = (1,20,0.5), plot_num = (1,9,1),
                         save = [False, True])
        display(LL)
    if (plot_type == 'Longitude-latitude difference plot'):
        LLD = interactive(Lat_Lon_Difference_Plot, field=ds1.data_vars.keys(),
                          Dataset1 = ['DS1','DS2','DS3','DS4','DS5'],
                          Dataset2 = ['DS1','DS2','DS3','DS4','DS5'],
                          logtop=(-5,2,0.5), level=(0,69,1),cmap=cmaps, fig_height = (1,20,0.5), fig_width = (1,20,0.5), 
                          plot_num = [1,2,3],percentage = [False, True], save = [False, True])
        display(LLD)
        
    #Zonal mean plots
    if (plot_type == 'Zonal mean plot'):
        ZM = interactive(Zonal_Mean_Plot, field=ds1.data_vars.keys(), logtop=(-5,2,0.5), cmap=cmaps, 
                         fig_height = (1,20,0.5), fig_width = (1,20,0.5), plot_num = (1,9,1),
                         Contours = [False, True], Levels = (1,15,1), save = [False, True])
        display(ZM)
    if (plot_type == 'Zonal mean difference plot'):
        ZMD = interactive(Zonal_Mean_Difference_plot, field=ds1.data_vars.keys(),
                          Dataset1 = ['DS1','DS2','DS3','DS4','DS5'],
                          Dataset2 = ['DS1','DS2','DS3','DS4','DS5'],
                          logtop=(-5,2,0.5), cmap=cmaps, fig_height = (1,20,0.5), fig_width = (1,20,0.5),
                          percentage = [False, True], Contours = [False, True], Levels = (1,15,1), save = [False, True])
        display(ZMD)
        
    #Fixed longitude plots   
    if (plot_type == 'Fixed longitude plot'):
        FL = interactive(Fixed_Lon_Plot, field=ds1.data_vars.keys(), logtop=(-5,2,0.5), lon_index=(0,143,1),cmap=cmaps, 
                         fig_height = (1,20,0.5), fig_width = (1,20,0.5), plot_num = (1,9,1),
                         save = [False, True])
        display(FL)
    if (plot_type == 'Fixed longitude difference plot'):
        FLD = interactive(Fixed_Lon_Difference_Plot, field=ds1.data_vars.keys(), logtop=(-5,2,0.5), 
                          Dataset1 = ['DS1','DS2','DS3','DS4','DS5'],
                          Dataset2 = ['DS1','DS2','DS3','DS4','DS5'],
                          lon_index=(0,143,1),cmap=cmaps, fig_height = (1,20,0.5), fig_width = (1,20,0.5),
                          plot_num = [1,2,3], percentage = [False, True], save = [False, True])
        display(FLD)
        
    #2D projection of a spherical Earth plot    
    if (plot_type == 'Earth plot'):
        EP = interactive(Earth_Plot, field=ds1.data_vars.keys(), plot_num = (1,9,1), 
                         lon = (0,359,1), lat  = (-90,90,1), cmap=cmaps,
                   fig_height = (1,20,0.5), fig_width = (1,20,0.5), level = (0,69,1), save = [False, True])
        display(EP)
        
    #Earth vector plot - currently implemented for wind.
    if (plot_type == 'Earth vector plot'):
        EVP = interactive(Plot_Earth_Vectors, plot_num = (1,9,1), lon = (0,359,1), 
                         lat  = (-90,90,1), fig_height = (1,20,0.5), fig_width = (1,20,0.5), 
                       Borders = [False, True], Land = [False, True], Ocean = [False, True], 
                          Grid = [False, True], Rivers_Lakes = [False, True])
        display(EVP)
    #Plot many different vertical profiles next to each other
    if (plot_type == 'Plot vertical: various'):
        PLV = interactive(Plot_Many_Vertical, plot_num = (1,12,1),ds_num = (1,9,1), logtop=(-5,2,0.5), field1 = ds1.data_vars.keys(),
                          field2 = ds1.data_vars.keys(), field3 = ds1.data_vars.keys(),
                       field4 = ds1.data_vars.keys(), field5 = ds1.data_vars.keys(), field6 = ds1.data_vars.keys(),
                          field7 = ds1.data_vars.keys(), field8 = ds1.data_vars.keys(), field9 = ds1.data_vars.keys(),
                       field10 = ds1.data_vars.keys(), field11 = ds1.data_vars.keys(), field12 = ds1.data_vars.keys(),
                          legend_pos = (1,12,1),
                          fig_height = (1,20,0.5), fig_width = (1,20,0.5), save = [False, True])
        display(PLV)    
    #Plot many different vertical profiles next to each other
    if (plot_type == 'Plot 2D field'):
        P2D = interactive(Two_D_Plot, plot_num = (1,9,1), field = ds1.data_vars.keys(), cmap = cmaps, 
                          fig_height = (1,20,0.5), fig_width = (1,20,0.5),
                          Contours = [False, True], Levels = (1,15,1), save = [False, True])
        display(P2D)   

Final_Widget = interactive(final_widget,
                 plot_type = ['Vertical profile plot', 'Vertical profile difference plot','Add variables, vertical plot',
                              'Longitude-latitude plot', 'Longitude-latitude plot difference plot',
                              'Zonal mean plot','Zonal mean difference plot',
                              'Fixed longitude plot', 'Fixed longitude difference plot', 
                              'Earth plot', 'Earth vector plot', 'Plot vertical: various', 'Plot 2D field'])

output = Final_Widget.children[-1]
output.layout.height = '1000px'
display(Final_Widget)
Final_Widget.update
# Out:
# interactive(children=(Dropdown(description='plot_type', options=('Vertical profile plot', 'Vertical profile di…
# <bound method interactive.update of interactive(children=(Dropdown(description='plot_type', options=('Vertical profile plot', 'Vertical profile difference plot', 'Add variables, vertical plot', 'Longitude-latitude plot', 'Longitude-latitude plot difference plot', 'Zonal mean plot', 'Zonal mean difference plot', 'Fixed longitude plot', 'Fixed longitude difference plot', 'Earth plot', 'Earth vector plot', 'Plot vertical: various', 'Plot 2D field'), value='Vertical profile plot'), Output(layout=Layout(height='1000px'))), _dom_classes=('widget-interact',))>

# %%
# export widget
from ipywidgets.embed import embed_minimal_html
embed_minimal_html('WACCM_Widget.html', views=[Final_Widget], title='WACCM_Widgets')

"""
original code that works:

    from ipywidgets import IntSlider
    from ipywidgets.embed import embed_minimal_html

    slider = IntSlider(value=40)
    embed_minimal_html('export.html', views=[slider], title='Widgets export')

"""
# Out:
# "\noriginal code that works:\n\n    from ipywidgets import IntSlider\n    from ipywidgets.embed import embed_minimal_html\n\n    slider = IntSlider(value=40)\n    embed_minimal_html('export.html', views=[slider], title='Widgets export')\n\n"
